# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("netflix_data.csv",index_col=0)

# %%
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.shape
# Out:
# (100, 11)

# %%
df['duration']  ##series
# Out:
# show_id
# s1         90 min
# s2      2 Seasons
# s3       1 Season
# s4       1 Season
# s5      2 Seasons
#           ...
# s96     3 Seasons
# s97        97 min
# s98     2 Seasons
# s99      1 Season
# s100     1 Season
# Name: duration, Length: 100, dtype: object

# %%
df[['duration']]        ##dataframe
# Out:
#           duration
# show_id
# s1          90 min
# s2       2 Seasons
# s3        1 Season
# s4        1 Season
# s5       2 Seasons
# ...            ...
# s96      3 Seasons
# s97         97 min
# s98      2 Seasons
# s99       1 Season
# s100      1 Season
#
# [100 rows x 1 columns]

# %%
s1_duration=df.loc[['s1'],['duration']]
s1_duration
# Out:
#         duration
# show_id
# s1        90 min

# %%
ds1_duration_iloc=df.iloc[[0],[8]]       
ds1_duration_iloc
# Out:
#         duration
# show_id
# s1        90 min

# %%
release_yr=df[df['release_year']==2020]
release_yr
# Out:
#             type                                              title  \
# show_id
# s1         Movie                               Dick Johnson Is Dead
# s17        Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# s18      TV Show                                    Falsa identidad
# s33      TV Show                                      Sex Education
# s35      TV Show                            Tayo and Little Wizards
# s48      TV Show                              The Smart Money Woman
# s79        Movie                                     Tughlaq Durbar
# s85        Movie                               Omo Ghetto: the Saga
#
#                                               director  \
# show_id
# s1                                     Kirsten Johnson
# s17      Pedro de Echave García, Pablo Azorín Williams
# s18                                                NaN
# s33                                                NaN
# s35                                                NaN
# ...

# %%
new_df=release_yr.loc[:,["title","release_year","duration"]]
new_df
# Out:
#                                                      title  release_year  \
# show_id
# s1                                    Dick Johnson Is Dead          2020
# s17      Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# s18                                        Falsa identidad          2020
# s33                                          Sex Education          2020
# s35                                Tayo and Little Wizards          2020
# s48                                  The Smart Money Woman          2020
# s79                                         Tughlaq Durbar          2020
# s85                                   Omo Ghetto: the Saga          2020
#
#           duration
# show_id
# s1          90 min
# s17         67 min
# s18      2 Seasons
# s33      3 Seasons
# s35       1 Season
# s48       1 Season
# s79        145 min
# s85        147 min

# %%
new_df['duration_num'] = new_df['duration'].str.extract(r'(\d+)').astype(int)
new_df
# Out:
#                                                      title  release_year  \
# show_id
# s1                                    Dick Johnson Is Dead          2020
# s17      Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# s18                                        Falsa identidad          2020
# s33                                          Sex Education          2020
# s35                                Tayo and Little Wizards          2020
# s48                                  The Smart Money Woman          2020
# s79                                         Tughlaq Durbar          2020
# s85                                   Omo Ghetto: the Saga          2020
#
#           duration  duration_num
# show_id
# s1          90 min            90
# s17         67 min            67
# s18      2 Seasons             2
# s33      3 Seasons             3
# s35       1 Season             1
# s48       1 Season             1
# s79        145 min           145
# ...

# %%
new_df['duration_num']=new_df['duration_num'].apply(lambda x:x*24 if x<=3 else x)
new_df
# Out:
#                                                      title  release_year  \
# show_id
# s1                                    Dick Johnson Is Dead          2020
# s17      Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# s18                                        Falsa identidad          2020
# s33                                          Sex Education          2020
# s35                                Tayo and Little Wizards          2020
# s48                                  The Smart Money Woman          2020
# s79                                         Tughlaq Durbar          2020
# s85                                   Omo Ghetto: the Saga          2020
#
#           duration  duration_num
# show_id
# s1          90 min            90
# s17         67 min            67
# s18      2 Seasons            48
# s33      3 Seasons            72
# s35       1 Season            24
# s48       1 Season            24
# s79        145 min           145
# ...

# %%
new_df['type_of_film']=new_df["duration_num"].apply(lambda x: 'short' if x <90 else 'long')
new_df
# Out:
#                                                      title  release_year  \
# show_id
# s1                                    Dick Johnson Is Dead          2020
# s17      Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# s18                                        Falsa identidad          2020
# s33                                          Sex Education          2020
# s35                                Tayo and Little Wizards          2020
# s48                                  The Smart Money Woman          2020
# s79                                         Tughlaq Durbar          2020
# s85                                   Omo Ghetto: the Saga          2020
#
#           duration  duration_num type_of_film
# show_id
# s1          90 min            90         long
# s17         67 min            67        short
# s18      2 Seasons            48        short
# s33      3 Seasons            72        short
# s35       1 Season            24        short
# ...

# %%
new_df['listed_in']=df['listed_in']
new_df
# Out:
#                                                      title  release_year  \
# show_id
# s1                                    Dick Johnson Is Dead          2020
# s17      Europe's Most Dangerous Man: Otto Skorzeny in ...          2020
# s18                                        Falsa identidad          2020
# s33                                          Sex Education          2020
# s35                                Tayo and Little Wizards          2020
# s48                                  The Smart Money Woman          2020
# s79                                         Tughlaq Durbar          2020
# s85                                   Omo Ghetto: the Saga          2020
#
#           duration  duration_num type_of_film  \
# show_id
# s1          90 min            90         long
# s17         67 min            67        short
# s18      2 Seasons            48        short
# s33      3 Seasons            72        short
# s35       1 Season            24        short
# ...

# %%
plt.plot(new_df['release_year'],new_df['duration_num'])
plt.xlabel('release_year')
plt.ylabel('duration_num')
plt.title("pratice")
plt.show()
